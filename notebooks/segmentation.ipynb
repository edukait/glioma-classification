# %% [markdown]
# # Segmentation
# The purpose of this code is to perform the segmentation of the brain tumor for subsequent feature extraction. The segmentation is the second step of this multi-step process, with the first step being image preprocessing, the second being segmentation, and the third being classification. This code is sourced from user [Issam28](https://github.com/Issam28/Brain-tumor-segmentation) on GitHub, who uses a CNN. This notebook will serve as a synthesis of all the different files in the repository with a few needed tweaks.

# %% [markdown]
# We must also need to install a package to read NiFTI files.

# %%
# !pip install --quiet nibabel
import nibabel as nib

# %% [markdown]
# ## Evaluation Metrics
# This code will create evaluation metrics that will assess how accurately the model can automatically segment the tumor. We will first add the necessary import statements.

# %%
import numpy as np
from scipy import ndimage

# %% [markdown]
# We will then create the method used to calculate the Dice score of two 3D volumes. The Dice score is a statistic used to assess the performance of image segmentation methods. The higher the Dice score, the more accurate the segmentation model is.

# %%
def binary_dice3d(s, g):
    # g=np.transpose(g,(2, 1, 0))
    num = np.sum(np.multiply(s, g))
    denom = s.sum() + g.sum()
    if denom == 0:
        return 1
    else:
        return 2.0 * num / denom

# %% [markdown]
# The next method we will define will calculate the sensitivity and specificity metrics, or the false negative rate and false positive rates, respectively.

# %%
def sensitivity(seg, ground):
    # ground =np.transpose(ground,(2, 1, 0))
    num = np.sum(np.multiply(ground, seg))
    denom = np.sum(ground)
    if denom == 0:
        return 1
    else:
        return num / denom

    
def specificity(seg, ground):
    # ground =np.transpose(ground,(2, 1, 0))
    num = np.sum(np.multiply(ground == 0, seg == 0))
    denom = np.sum(ground == 0)
    if denom == 0:
        return 1
    else:
        return num / denom

# %% [markdown]
# The next method will create a border for any given 3D image.

# %%
def border_map(binary_img, n):
    binary_map = np.asarray(binary_img, dtype = np.uint8)
    neigh = n
    west = ndimage.shift(binary_map, [-1, 0, 0], order = 0)
    east = ndimage.shift(binary_map, [1, 0, 0], order = 0)
    north = ndimage.shift(binary_map, [0, 1, 0], order = 0)
    south = ndimage.shift(binary_map, [0, -1, 0], order = 0)
    top = ndimage.shift(binary_map, [0, 0, 1], order = 0)
    bottom = ndimage.shift(binary_map, [0, 0, -1], order = 0)
    cumulative = west + east + north + south + top + bottom
    border = ((cumulative < 6) * binary_map) == 1
    return border

# %% [markdown]
# The method `border_distance` will create a map of the distances from the borders of the segmentation and the reference image, as well as the border maps themselves. The reference image, or `ref` is the correctly labeled MRI image of the tumor, while the segmentation, or `seg` is the model's attempt at segmenting the tumor.

# %%
def border_distance(ref, seg):
    neigh = 8
    border_ref = border_map(seg, neigh)
    border_seg = border_map(seg, neigh)
    oppose_ref = 1 - ref
    oppose_seg = 1 - seg
    # euclidean distance transform
    distance_ref = ndimage.distance_transform_edt(oppose_ref)
    distance_seg = ndimage.distance_transform_edt(oppose_seg)
    distance_border_seg = border_ref * distance_seg
    distance_border_ref = border_seg * distance_ref
    return distance_border_ref, distance_border_seg

# %% [markdown]
# This next method will calculate the average symmetric distance and subsequently the Hausdorff distance between a segmentation and a reference image. The Hausdorff distance measures how far two subsets of a metric space are from each other. The average symmetric distance essentially calculates how accurate the segmentation of the image is compared to the reference. A perfect segmentation has an average symmetric distance value of 0.

# %%
def Hausdorff_distance(ref, seg):
    ref_border_dist, seg_border_dist = border_distance(ref, seg)
    hausdorff_distance = np.max([np.max(ref_border_dist), 
                               np.max(seg_border_dist)])
    return hausdorff_distance

# %% [markdown]
# The next three methods will compute the Dice score for the whole tumor, the enhancing region, and the core region, respectively. The enhancing region of a tumor is defined as the region that continues to spread and grow, and the core region is the localized center of the tumor.

# %%
# whole region
def DSC_whole(pred, orig_label):
    return binary_dice3d(pred > 0, orig_label > 0)


# enhancing region
def DSC_en(pred, orig_label):
    return binary_dice3d(pred == 4, orig_label == 4)


# core region
def DSC_core(pred, orig_label):
    seg_ = np.copy(pred)
    ground_ = np.copy(orig_label)
    seg_[seg_ == 2] = 0
    ground_[ground_ == 2] = 0
    return binary_dice3d(seg_ > 0, ground_ > 0)

# %% [markdown]
# We will repeat this process for the specificity metric (false positive rate).

# %%
# whole region
def specificity_whole(seg, ground):
    return specificity(seg > 0, ground > 0)


# enhancing region
def specificity_en(seg, ground):
    return specificity(seg == 4, ground == 4)


# core region
def specificity_core(seg, ground):
    seg_ = np.copy(seg)
    ground_ = np.copy(ground)
    seg_[seg_ == 2] = 0
    ground_[ground_ == 2] = 0
    return specificity(seg_ > 0, ground_ > 0)

# %% [markdown]
# And also the sensitivity metric.

# %%
def sensitivity_whole(seg,ground):
    return sensitivity(seg>0,ground>0)

def sensitivity_en(seg,ground):
    return sensitivity(seg==4,ground==4)

def sensitivity_core(seg,ground):
    seg_=np.copy(seg)
    ground_=np.copy(ground)
    seg_[seg_==2]=0
    ground_[ground_==2]=0
    return sensitivity(seg_>0,ground_>0)

# %% [markdown]
# Lastly, we will finish with finding the Hausdorff distance in the same manner with three methods.

# %%
# whole region
def hausdorff_whole(seg, ground):
    return Hausdorff_distance(seg == 0, ground == 0)


# enhancing region
def hausdorff_en(seg, ground):
    return Hausdorff_distance(seg != 4, ground != 4)


# core region
def hausdorff_core(seg, ground):
    seg_ = np.copy(seg)
    ground_ = np.copy(ground)
    seg_[seg_== 2] = 0
    ground_[ground_ == 2] = 0
    return Hausdorff_distance(seg_ == 0, ground_ == 0)

# %% [markdown]
# ## Loss Functions
# This code will define the loss functions for the model itself. We will be using the Tensorflow backend, which is needed for low-level operations such as tensor products and convolutions, which we will need to import.

# %%
# !pip install keras
# !pip install -U tensorflow
import keras.backend as K
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# The next four methods, the Dice score will be computed on two tensors (often thought of as a generalized matrix that can take on any numerical dimension), the whole tumor, the enhancing region, and the core region, respectively. Note that this is varies from the methods defined above in that the above methods assess the model after prediction, while these methods are defined and used during the actual running of the model.

# %%
# two tensors
def dice(y_true, y_pred):
    #computes the dice score on two tensors
    sum_p=K.sum(y_pred,axis=0)
    sum_r=K.sum(y_true,axis=0)
    sum_pr=K.sum(y_true * y_pred,axis=0)
    dice_numerator =2*sum_pr
    dice_denominator =sum_r+sum_p
    dice_score =(dice_numerator+K.epsilon() )/(dice_denominator+K.epsilon())
    return dice_score


# whole tumor
def dice_whole_metric(y_true, y_pred):
    y_true_f = K.reshape(y_true,shape=(-1,4))
    y_pred_f = K.reshape(y_pred,shape=(-1,4))
    y_whole=K.sum(y_true_f[:,1:],axis=1)
    p_whole=K.sum(y_pred_f[:,1:],axis=1)
    dice_whole=dice(y_whole,p_whole)
    return dice_whole


# enhancing region
def dice_en_metric(y_true, y_pred):
    y_true_f = K.reshape(y_true,shape=(-1,4))
    y_pred_f = K.reshape(y_pred,shape=(-1,4))
    y_enh=y_true_f[:,-1]
    p_enh=y_pred_f[:,-1]
    dice_en=dice(y_enh,p_enh)
    return dice_en


# core region
def dice_core_metric(y_true, y_pred):
    y_true_f = K.reshape(y_true,shape=(-1,4))
    y_pred_f = K.reshape(y_pred,shape=(-1,4))

    #workaround for tf
    y_core=K.sum(tf.gather(y_true_f, [1,3],axis =1),axis=1)
    p_core=K.sum(tf.gather(y_pred_f, [1,3],axis =1),axis=1)

    #y_core=K.sum(y_true_f[:,[1,3]],axis=1)
    #p_core=K.sum(y_pred_f[:,[1,3]],axis=1)
    dice_core=dice(y_core,p_core)
    return dice_core

# %% [markdown]
# We will also need to define a weighted logarithmic loss function, which will have three parts. The first part will scale predictions so that the class predictions of each sample sum to 1. Then, we will clip to prevent `NaN` and `Inf` values. Lastly, weights will be assigned in the following order: normal, necrotic, edema, and enhancing. Necrotic brain tissue is unhealthily soft brain tissue, and edema is the accumulation of excess fluid in fluid compartments.

# %%
def weighted_log_loss(y_true, y_pred):
    # scale predictions
    y_pred /= K.sum(y_pred, axis = 1, keepdims = True)

    # clip to prevent NaN's and Inf's
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())

    # weights are assigned in this order: normal, necrotic, edema, enchancing
    weights = np.array([1, 5, 2, 4])
    weights = K.variable(weights)
    loss = y_true * K.log(y_pred) * weights
    loss = K.mean(-K.sum(loss, -1))
    return loss

# %% [markdown]
# The next method will compute the sum of two loss functions: the generalized dice loss function and the weighted cross-entropy function, which was the previously defined `weighted_log_loss` function. This will serve as our primary loss function for the model.

# %%
def gen_dice_loss(y_true, y_pred):
    y_true_f = K.reshape(y_true, shape = (-1, 4))
    y_pred_f = K.reshape(y_pred, shape = (-1, 4))
    sum_p = K.sum(y_pred_f, axis = -2)
    sum_r = K.sum(y_true_f, axis = -2)
    sum_pr = K.sum(y_true_f * y_pred_f, axis = -2)
    weights = K.pow(K.square(sum_r) + K.epsilon(), -1)
    generalized_dice_numerator = 2 * K.sum(weights * sum_pr)
    generalized_dice_denominator = K.sum(weights * (sum_r + sum_p))
    generalized_dice_score = generalized_dice_numerator / generalized_dice_denominator
    GDL = 1 - generalized_dice_score
    del sum_p, sum_r, sum_pr, weights
    return GDL + weighted_log_loss(y_true, y_pred)

# %% [markdown]
# ## Model Creation
# Code that creates the model class, which is a convolutional neural network. We will need multiple functions and modules from the Keras library, which we will import.

# %%
from keras.models import Model, load_model
from keras.layers.advanced_activations import PReLU
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Dropout, GaussianNoise, Input, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers import Conv2DTranspose, UpSampling2D, concatenate, add
from keras.optimizers import SGD

# %% [markdown]
# Before creating the model, we must also set the image data format to `channels_last`. This parameter affects how the Tensorflow backend treats the data dimensions when working with convolutions in the model. This is the way that the data is stored as convolutions are performed.

# %%
K.set_image_data_format("channels_last")

# %% [markdown]
# Now, we will actually create the model class, called U-Net. The U-Net model will have an encoding unit as well as a decoding unit, a batch normalization layer, a `PReLU` activation layer in the hidden layers, a 2D convolutional layer, and a `softmax`activation layer as the output.

# %%
class Unet_model(object):

    
    # constructor
    def __init__(self, img_shape, load_model_weights = None):
        self.img_shape = img_shape
        self.load_model_weights = load_model_weights
        self.model = self.compile_unet()
  

    # compile the u-net model
    def compile_unet(self):
        i = Input(shape = self.img_shape)
        # add gaussian noise to the first layer to combat overfitting
        i_ = GaussianNoise(0.01)(i)
        i_ = Conv2D(64, 2, padding = 'same', data_format = 'channels_last')(i_)
        out = self.unet(inputs = i_)
        model = Model(input = i, output = out)
    
        sgd = SGD(lr = 0.08, momentum = 0.9, decay = 5e-6, nesterov = False) ## Look at this documentation for saving?
        model.compile(loss = gen_dice_loss, optimizer = sgd, 
                      metrics = [dice_whole_metric, dice_core_metric, dice_en_metric])
        # load weights if set for prediction
        if self.load_model_weights is not None:
            model.load_weights(self.load_model_weights)
        return model
  

    # the actual u-net architecture
    def unet(self, inputs, nb_classes = 4, start_ch = 64, depth = 3, inc_rate = 2.,
          activation = 'relu', dropout = 0.0, batchnorm = True, upconv = True, format_='channels_last'):
        o = self.level_block(inputs, start_ch, depth, inc_rate, activation, dropout, batchnorm, upconv, format_)
        o = BatchNormalization()(o)
        o = PReLU(shared_axes=[1, 2])(o)
        o = Conv2D(nb_classes, 1, padding = 'same', data_format = format_)(o)
        o = Activation('softmax')(o)
        return o
  

    def level_block(self,m, dim, depth, inc, acti, do, bn, up,format_="channels_last"):
        if depth > 0:
            n = self.res_block_enc(m,0.0,dim,acti, bn,format_)
            # print("n after res_block_enc", n.shape)
            #using strided 2D conv for donwsampling
            m = Conv2D(int(inc*dim), 2,strides=2, padding='same',data_format = format_)(n)
            # print("m after conv2d", m.shape)
            m = self.level_block(m,int(inc*dim), depth-1, inc, acti, do, bn, up )
            if up:
                m = UpSampling2D(size=(2, 2),data_format = format_)(m)
                # print("m after upsampling", m.shape)
                m = Conv2D(dim, 2, padding='same',data_format = format_)(m)
                # print("m after conv2d", m.shape)
            else:
                m = Conv2DTranspose(dim, 3, strides=2,padding='same',data_format = format_)(m)
                # print("m after conv2dtranspose", m.shape)
            n=concatenate([n,m])
            #the decoding path
            m = self.res_block_dec(n, 0.0,dim, acti, bn, format_)
        else:
            m = self.res_block_enc(m, 0.0,dim, acti, bn, format_)
        return m

    
    def res_block_enc(self,m, drpout,dim,acti, bn,format_="channels_last"):
        
        """
        the encoding unit which a residual block
        """
        n = BatchNormalization()(m) if bn else n
        #n=  Activation(acti)(n)
        n=PReLU(shared_axes=[1, 2])(n)
        n = Conv2D(dim, 3, padding='same',data_format = format_)(n)
                
        n = BatchNormalization()(n) if bn else n
        #n=  Activation(acti)(n)
        n=PReLU(shared_axes=[1, 2])(n)
        n = Conv2D(dim, 3, padding='same',data_format =format_ )(n)

        n=add([m,n]) 
        
        return  n 
  

    def res_block_dec(self,m, drpout,dim,acti, bn,format_="channels_last"):

        """
        the decoding unit which a residual block
        """
         
        n = BatchNormalization()(m) if bn else n
        #n=  Activation(acti)(n)
        n=PReLU(shared_axes=[1, 2])(n)
        n = Conv2D(dim, 3, padding='same',data_format = format_)(n)

        n = BatchNormalization()(n) if bn else n
        #n=  Activation(acti)(n)
        n=PReLU(shared_axes=[1, 2])(n)
        n = Conv2D(dim, 3, padding='same',data_format =format_ )(n)
        
        Save = Conv2D(dim, 1, padding='same',data_format = format_,use_bias=False)(m) 
        n=add([Save,n]) 
        
        return  n

# %% [markdown]
# ## Patch Extraction
# This code will sample patches of the MRI images that will be used for training. This patch extraction greatly reduces computational time. We will begin by importing the necessary modules and methods.

# %%
# !pip install SimpleITK
# Out:
# Requirement already satisfied: SimpleITK in /anaconda3/lib/python3.6/site-packages (1.2.0)

# %%
import random
from skimage import io
import numpy as np
from glob import glob
import SimpleITK as sitk
from keras.utils import np_utils

# %% [markdown]
# We will create a Pipeline class for the process of extracting random patches of the 3D images for training the model. The Pipeline class will also contain methods to normalize the batches.

# %%
class Pipeline(object):
  

    # constructor
    def __init__(self, list_train, Normalize = True):
        self.scans_train = list_train
        self.train_im = self.read_scans(Normalize)
  

    '''
    input: unnormalized slice
    output: normalized clipped slice
    '''
    def _normalize(self, slice):
        b = np.percentile(slice, 99)
        t = np.percentile(slice, 1)
        slice = np.clip(slice, t, b)
        image_nonzero = slice[np.nonzero(slice)]
        if np.std(slice) == 0 or np.std(image_nonzero) == 0:
            return slice
        else:
            tmp = (slice - np.mean(image_nonzero)) / np.std(image_nonzero)
            # since the range of intensities is between 0 and 5000, the min in the
            # normalized slice corresponds to 0 intensity in unnormalized slice
            # the min is replaced with -9 just to keep track of 0 intensities so that
            # we can discard those intensities afterwards when sampling random patches
            tmp[tmp == tmp.min()] = -9
            return tmp
  

    '''
    normalizes each slice
    subtracts mean and div by std dev for each slice
    clips top and bottom one percent of pixel intensities
    '''
    def norm_slices(self, slice_not):
        normed_slices = np.zeros((5, 155, 240, 240)).astype(np.float32)
        for slice_ix in range(4):
            normed_slices[slice_ix] = slice_not[slice_ix]
            for mode_ix in range(155):
                normed_slices[slice_ix][mode_ix] = self._normalize(slice_not[slice_ix][mode_ix])
        normed_slices[-1] = slice_not[-1]

        return normed_slices

    
    '''
    concatenate two parts in one dataset
    this can be avoided if there is enough RAM
    '''
    def concatenate():
        Y_labels_2 = np.load("y_dataset_second_part.npy").astype(np.uint8)
        X_patches_2 = np.load("x_dataset_second_part.npy").astype(np.float32)
        Y_labels_1 = np.load("y_dataset_first_part.npy").astype(np.uint8)
        X_patches_1 = np.load("x_dataset_first_part.npy").astype(np.float32)

        # concatenate both parts
        X_patches = np.concatenate((X_patches_1, X_patches_2), axis = 0)
        Y_labels = np.concatenate((Y_labels_1, Y_labels_2), axis = 0)
        del Y_labels_2, X_patches_2, Y_labels_1, X_patches_1

        # shuffle the entire dataset
        shuffle = list(zip(X_patches, Y_labels))
        np.random.seed(138)
        np.random.shuffle(shuffle)
        X_patches = np.array([shuffle[i][0] for i in range(len(shuffle))])
        Y_labels = np.array([shuffle[i][1] for i in range(len(shuffle))])
        del shuffle

        np.save("x_training", X_patches.astype(np.float32))
        np.save("y_training", Y_labels.astype(np.uint8))
  

    def read_scans(self, Normalize):
        print("reading scans...")
        train_images = []
        count = 0
        for i in range(len(self.scans_train)):
            if i % 10 == 0:
                print('iteration [{}]'.format(i))
            folder_name = self.scans_train[i][self.scans_train[i].rfind('/')+1:]
            flair = glob(self.scans_train[i] + '/*_flair.nii.gz')
            t2 = glob(self.scans_train[i] + '/*_t2.nii.gz')
            gt = glob(self.scans_train[i] + '/*_seg.nii.gz')
            t1 = glob(self.scans_train[i] + '/*_t1.nii.gz')
            t1c = glob(self.scans_train[i] + '/*_t1ce.nii.gz')

            if (len(flair) + len(t2) + len(gt) + len(t1) + len(t1c)) < 5:
                # print("there's a problem here. problem lies in this patient:", folder_name)
                count = count + 1
                continue
            scans = [flair[0], t1[0], t1c[0], t2[0], gt[0]]

            # read a volume composed of 5 modalities
            # print(scans)
            tmp = []
            for k in range(len(scans)):
                img = np.array(nib.load(scans[k]).dataobj)
                tmp.append(img)
            
            tmp = np.transpose(tmp, (0, 3, 2, 1))
            # normalize each slice
            if Normalize == True:
                tmp = self.norm_slices(tmp)

            train_images.append(tmp)
            del tmp
        print("finished reading")
        print(count, "invalid folders/patients")
        return np.array(train_images)
    
    
    ''' 
    input:
    num_patches: the total number of sampled patches
    d: this corresponds to the number of channels (1 modality)
    h: height of the patch
    w: width of the patch

    output:
    patches: np array containing the randomly sampled patches
    labels: np array containing the corresponding target patches
    '''
    def sample_patches_randomly(self, num_patches, d, h, w):
        print("begin sample_patches_randomly function")
        patches = []
        labels = []
        count = 0

        # swap axes to make axis 0 represent the modality and axis 1 represent the slice
        # take the ground truth
        gt_im = np.swapaxes(self.train_im, 0, 1)[4]

        # take the flair image as a mask
        msk = np.swapaxes(self.train_im, 0, 1)[0]
        # save the shape of the ground truth to use it afterwards
        tmp_shp = gt_im.shape

        # reshape the mask and the ground truth to a 1D array
        gt_im = gt_im.reshape(-1).astype(np.uint8)
        msk = msk.reshape(-1).astype(np.float32)

        # maintain list of 1D indices while discarding 0 intensities
        indices = np.squeeze(np.argwhere((msk != -9.0) & (msk != 0.0)))
        del msk

        # shuffle the list of indices of the class
        np.random.shuffle(indices)

        # reshape gt_im
        gt_im = gt_im.reshape(tmp_shp)

        # a loop to sample the patches from the images
        i = 0
        pix = len(indices)
        print("sampling patches")
        while (count < num_patches) and (pix > i):
            # randomly choose an index
            ind = indices[i]
            i += 1
            # reshape ind to 3D index
            ind = np.unravel_index(ind, tmp_shp)
            # get the patient and the slice id (might need to rework)
            patient_id = ind[0]
            slice_idx = ind[1]
            p = ind[2:]
            # construct the patch by defining the coordinates
            p_y = (p[0] - (h)/2, p[0] + (h)/2)
            p_x = (p[1] - (w)/2, p[1] + (w)/2)
            p_x = list(map(int, p_x))
            p_y = list(map(int, p_y))

            # take patches from the modalities
            tmp = self.train_im[patient_id][0:4, slice_idx, p_y[0]:p_y[1], p_x[0]:p_x[1]]
            # take the corresponding label patch (might need to rework later)
            lbl = gt_im[patient_id, slice_idx, p_y[0]:p_y[1], p_x[0]:p_x[1]]

            # keep only patches that have the desired size
            if tmp.shape != (d, h, w):
                continue
            patches.append(tmp)
            labels.append(lbl)
            count += 1
        patches = np.array(patches)
        labels = np.array(labels)
        return patches, labels

# %% [markdown]
# ## Training
# Now, we will train the model on the training dataset. We will add the necessary import statements.

# %%
import json
from keras.models import model_from_json, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, Callback, LearningRateScheduler

# %% [markdown]
# We will also be creating an `SGDLearningRateTracker` class. As the learning rate (`lr`) and `decay` values of the model change, this class will notify us of those changes in the model.

# %%
class SGDLearningRateTracker(Callback):
    def on_epoch_begin(self, epoch, logs = {}):
        optimizer = self.model.optimizer
        lr = K.get_value(optimizer.lr)
        decay = K.get_value(optimizer.decay)
        lr = lr / 10
        decay = decay * 10
        K.set_value(optimizer.lr, lr)
        K.set_value(optimizer.decay, decay)
        print("lr changed to:", lr)
        print("decay changed to:", decay)

# %% [markdown]
# We will create a `Training` class, primarily to synthesize all of the methods into one class to reduce clunky code.

# %%
class Training(object):
    
            
    '''
    load a model
    input: string 'model_name': filepath to model and weights, not including extension
    output: model with loaded weights. can fit on model using loaded_model = True in fit_model method
    '''
    def load_model(self, model_name):
        '''
        Load a model
        INPUT  (1) string 'model_name': filepath to model and weights, not including extension
        OUTPUT: Model with loaded weights. can fit on model using loaded_model=True in fit_model method
        '''
        print ('Loading model {}'.format(model_name))
        model_toload = '/Users/kaitlinylim/Documents/tumorproj/models/{}.json'.format(model_name)
        weights = '/Users/kaitlinylim/Documents/tumorproj/weights/{}.hdf5'.format(model_name)
        with open(model_toload) as f:
            loaded_model_json = f.read()
        model_comp = model_from_json(loaded_model_json)
        model_comp.load_weights(weights)
        print ('model loaded.')
        model_comp.compile(loss = gen_dice_loss, optimizer = SGD(lr = 0.08, momentum = 0.9, decay = 5e-6, nesterov = False), 
                           metrics = [dice_whole_metric, dice_core_metric, dice_en_metric])
        print('model compiled')
        self.model = model_comp
        return model_comp

    
    # constructor
    def __init__(self, batch_size, nb_epoch, load_model_resume_training = None):
        self.batch_size = batch_size
        self.nb_epoch = nb_epoch

        #loading model from path to resume previous training without recompiling the whole model
        if load_model_resume_training is not None:
            # self.model = self.load_model(load_model_resume_training,custom_objects={'gen_dice_loss': gen_dice_loss,'dice_whole_metric':dice_whole_metric,'dice_core_metric':dice_core_metric,'dice_en_metric':dice_en_metric})
            self.model = self.load_model(load_model_resume_training)
            print("pre-trained model loaded!")
        else:
            unet = Unet_model(img_shape = (128, 128, 4))
            self.model = unet.model
            print("u-net cnn compiled!")

    
    def fit_unet(self, X33_train, Y_train, X_patches_valid = None, Y_labels_valid = None):
        train_generator = self.img_msk_gen(X33_train, Y_train, 9999)
        checkpointer = ModelCheckpoint(filepath = "/Users/kaitlinylim/Documents/tumorproj/checkpoints/ResUnet.{epoch:02d}_{val_loss:.3f}.hdf5",
                                      verbose = 1)
        self.model.fit_generator(train_generator, steps_per_epoch = len(X33_train)//self.batch_size,
                                epochs = self.nb_epoch, validation_data = (X_patches_valid, Y_labels_valid),
                                verbose = 1, callbacks = [checkpointer, SGDLearningRateTracker()])

        
    '''
    a custom generator that performs data augmentation on both patches and their corresponding masks
    '''
    def img_msk_gen(self, X33_train, Y_train, seed):
        datagen = ImageDataGenerator(horizontal_flip = True, data_format = 'channels_last')
        datagen_msk = ImageDataGenerator(horizontal_flip = True, data_format = 'channels_last')
        image_generator = datagen.flow(X33_train, batch_size = 4, seed = seed)
        y_generator = datagen_msk.flow(Y_train, batch_size = 4, seed = seed)
        while True:
            yield(image_generator.next(), y_generator.next())

            
    '''
    input: string 'model_name': path where to save model and weights without extension
    saves current model as json and weights as h5df file
    '''
    def save_model(self, model_name):
        model_tosave = '{}.json'.format(model_name)
        json_string = self.model.to_json()
        with open('/Users/kaitlinylim/Documents/tumorproj/models/'+model_tosave, 'w') as json_file:
            json_file.write(json_string)
            weights = '{}.hdf5'.format(model_name)
            self.model.save_weights('/Users/kaitlinylim/Documents/tumorproj/weights/'+weights)
        print ('model saved')

# %% [markdown]
# ## Prediction
# This is the code for the actual tumor segmentation. We will begin with import statements.

# %%
import os

# %% [markdown]
# As with the `Training` class, we will also create a `Prediction` class to streamline the predicting process.

# %%
class Prediction(object):

    
    # constructor
    def __init__(self, batch_size_test, load_model_path):
        self.batch_size_test = batch_size_test
        unet = Unet_model(img_shape=(240, 240, 4), load_model_weights = load_model_path)
        self.model = unet.model
        print("u-net cnn model compiled\n")
  

    '''
    segment the input volume
    input: (1) str 'filepath_image': filepath of the volume to predict
     (2) bool 'show'
    output: (1) np array of the predicted volume
      (2) np array of the corresponding ground truth
    '''
    def predict_volume(self, filepath_image, show):
        
        '''
        segment the input volume
        INPUT   (1) str 'filepath_image': filepath of the volume to predict 
                (2) bool 'show': True to ,
        OUTPUt  (1) np array of the predicted volume
                (2) np array of the corresping ground truth
        '''
        
        #read the volume
        flair = glob(filepath_image + '/*_flair.nii.gz')
        t2 = glob(filepath_image + '/*_t2.nii.gz')
        gt = glob(filepath_image + '/*_seg.nii.gz')
        t1s = glob(filepath_image + '/*_t1.nii.gz')
        t1c = glob(filepath_image + '/*_t1ce.nii.gz')
        if (len(flair)+len(t2)+len(gt)+len(t1s)+len(t1c))<5:
            print("there is a problem here! the problem lies in this patient")
            return None, None
        scans_test = [flair[0], t1s[0], t1c[0], t2[0], gt[0]]
        # read a volume composed of 5 modalities
            # print(scans)
        test_im = []
        for k in range(len(scans_test)):
            img = np.array(nib.load(scans_test[k]).dataobj)
            test_im.append(img)

        
        test_im=np.array(test_im).astype(np.float32)
        test_image = test_im[0:4]
        gt=test_im[-1]
        gt[gt==4]=3
        gt = np.transpose(gt, (2, 1, 0))

        #normalize each slice following the same scheme used for training
        test_image = np.transpose(test_image, (0, 3, 2, 1))
        test_image=self.norm_slices(test_image)
        # print(test_image.shape)
        
        #transform the data to channels_last keras format
        test_image = test_image.swapaxes(0,1)
        # print(test_image.shape, 'after swapping axes')
        test_image=np.transpose(test_image,(0,2,3,1))
        # print(test_image.shape, 'after transposing')

        if show:
            verbose=1
        else:
            verbose=0
        # predict classes of each pixel based on the model
        prediction = self.model.predict(test_image,batch_size=self.batch_size_test,verbose=verbose)   
        prediction = np.argmax(prediction, axis=-1)
        prediction=prediction.astype(np.uint8)
        #reconstruct the initial target values .i.e. 0,1,2,4 for prediction and ground truth
        prediction[prediction==3]=4
        gt[gt==3]=4
        
        return np.array(prediction),np.array(gt)

    
    '''
    computes the evaluation metrics on the segmented volume
    input: (1) str 'filepath_image': filepath to test image for segmentation, including file extension
     (2) bool 'save': whether to save to disk or not
     (3) bool 'show': if true, prints the evaluation metrics
    output: np array of all evaluation metrics
    '''
    def evaluate_segmented_volume(self, filepath_image, save, show, save_path):
        predicted_images, gt = self.predict_volume(filepath_image, show)
        if predicted_images is None:
            return None

        if save:
            np.save('/Users/kaitlinylim/Documents/tumorproj/predictions/path_all_train/{}.npy'.format(save_path), predicted_images)
            # tmp = sitk.GetImageFromArray(predicted_images)
            # sitk.WriteImage(tmp,'/Users/kaitlinylim/Documents/tumorproj/predictions/{}.nii.gz'.format(save_path))

        # compute the evaluation metrics
        Dice_complete = DSC_whole(predicted_images, gt)
        Dice_enhancing = DSC_en(predicted_images, gt)
        Dice_core = DSC_core(predicted_images, gt)

        Sensitivity_whole = sensitivity_whole(predicted_images, gt)
        Sensitivity_en = sensitivity_en(predicted_images, gt)
        Sensitivity_core = sensitivity_core(predicted_images, gt)

        Specificity_whole = specificity_whole(predicted_images, gt)
        Specificity_en = specificity_en(predicted_images, gt)
        Specificity_core = specificity_core(predicted_images, gt)

        Hausdorff_whole = hausdorff_whole(predicted_images, gt)
        Hausdorff_en = hausdorff_en(predicted_images, gt)
        Hausdorff_core = hausdorff_core(predicted_images, gt)

        if show:
            print("************************************************************")
            print("Dice complete tumor score : {:0.4f}".format(Dice_complete))
            print("Dice core tumor score (tt sauf vert): {:0.4f}".format(Dice_core))
            print("Dice enhancing tumor score (jaune):{:0.4f} ".format(Dice_enhancing))
            print("**********************************************")
            print("Sensitivity complete tumor score : {:0.4f}".format(Sensitivity_whole))
            print("Sensitivity core tumor score (tt sauf vert): {:0.4f}".format(Sensitivity_core))
            print("Sensitivity enhancing tumor score (jaune):{:0.4f} ".format(Sensitivity_en))
            print("***********************************************")
            print("Specificity complete tumor score : {:0.4f}".format(Specificity_whole))
            print("Specificity core tumor score (tt sauf vert): {:0.4f}".format(Specificity_core))
            print("Specificity enhancing tumor score (jaune):{:0.4f} ".format(Specificity_en))
            print("***********************************************")
            print("Hausdorff complete tumor score : {:0.4f}".format(Hausdorff_whole))
            print("Hausdorff core tumor score (tt sauf vert): {:0.4f}".format(Hausdorff_core))
            print("Hausdorff enhancing tumor score (jaune):{:0.4f} ".format(Hausdorff_en))
            print("***************************************************************\n\n")

        return np.array((Dice_complete, Dice_core, Dice_enhancing,
                    Sensitivity_whole, Sensitivity_core, Sensitivity_en,
                    Specificity_whole, Specificity_core, Specificity_en,
                    Hausdorff_whole, Hausdorff_en, Hausdorff_en))
  

    '''
    returns an np array of predicted volumes
    '''
    def predict_multiple_volumes(self, filepath_volumes, save, show):
        results, ids = [], []
        for patient in filepath_volumes:
            tmp1 = patient.split('/')
            print("volume id:", tmp1[-2] + '/' + tmp1[-1])
            # might need to change save_path
            tmp=self.evaluate_segmented_volume(patient,save=save,show=show,save_path=os.path.basename(patient))
            if tmp is None:
                continue
            # save the results of each volume
            results.append(tmp)
            # save each id for later use
            ids.append(str(tmp1[-2] + '/' + tmp1[-1]))

        res = np.array(results)
        print("mean:", np.mean(res, axis = 0))
        print("std:", np.std(res, axis = 0))
        print("median:", np.median(res, axis = 0))
        print("25 quartile:", np.percentile(res, 25, axis = 0))
        print("75 quartile:", np.percentile(res, 75, axis = 0))
        print("max:", np.max(res, axis = 0))
        print("min:", np.min(res, axis = 0))

        # might need to change
        np.savetxt("/Users/kaitlinylim/Documents/tumorproj/predictions/path_all_train/results.out", res)
        np.savetxt("/Users/kaitlinylim/Documents/tumorproj/predictions/path_all_train/volumes_id.out", ids, fmt='%s')
        return res
  

    '''
    normalizes each slice, excluding gt
    subtracts mean and div by std dev for each slice
    clips top and bottom one percent of pixel intensities
    '''
    def norm_slices(self, slice_not):
        normed_slices = np.zeros((4, 155, 240, 240))
        for slice_ix in range(4):
            normed_slices[slice_ix] = slice_not[slice_ix]
            for mode_ix in range(155): #change this back to 155 if it doesn't work
                normed_slices[slice_ix][mode_ix] = self._normalize(slice_not[slice_ix][mode_ix])
        return normed_slices

    
    def _normalize(self, slice):
        b = np.percentile(slice, 99)
        t = np.percentile(slice, 1)
        slice = np.clip(slice, t, b)
        image_nonzero = slice[np.nonzero(slice)]

        if np.std(slice) == 0 or np.std(image_nonzero) == 0:
            return slice
        else:
            tmp = (slice - np.mean(image_nonzero)) / np.std(image_nonzero)
            tmp[tmp == tmp.min()] = -9
        return tmp

# %% [markdown]
# ## `Pipeline` Execution
# Now, we will actually use the `Pipeline`, `Training`, and `Prediction` classes. We will begin with the patch extraction with the `Pipeline` class. Note that as we convert the data in `Patches` and `Y_labels` to fit the `channels_last` format in Keras, we will need to one-hot encode the targets.

# %%
# paths to the BraTS 2018 dataset
path_HGG = glob('/Users/kaitlinylim/Documents/tumorproj/images/BraTS 2018 Training/HGG/**')
path_LGG = glob('/Users/kaitlinylim/Documents/tumorproj/images/BraTS 2018 Training/LGG/**')

# shuffle the datasets
np.random.seed(2022)
np.random.shuffle(path_HGG)
np.random.shuffle(path_LGG)

# %% [markdown]
# We will divide the data that we have into 80 percent training data and 20 percent testing.

# %%
train_val_HGG = (int)(len(path_HGG) * 0.8)
path_HGG_train = path_HGG[0:train_val_HGG]
path_HGG_test = path_HGG[train_val_HGG:]

train_val_LGG = (int)(len(path_LGG) * 0.8)
path_LGG_train = path_LGG[0:train_val_LGG]
path_LGG_test = path_LGG[train_val_LGG:]

path_all_train = path_HGG_train + path_LGG_train
path_all_test = path_HGG_test + path_LGG_test

print("total number of training images is", len(path_all_train))
# Out:
# total number of training images is 228

# %% [markdown]
# Now, we will create the pipeline that extracts patches from the MRI images.

# %%
pipeline = Pipeline(list_train = path_all_train)

# %% [markdown]
# Because we are only using MRI scans from patients that have all five modalities, we actually end up eliminating a lot of the patients. First, we will create the necessary variables that we need for the `sample_patches_randomly` method.

# %%
np.random.seed(1555)
# might need to change this
start = 0
end = 57
# set the total number of patches
# this formula extracts approximately 3 patches per slice
num_patches = 146 * (end - start) * 3
# define the size of a patch
h = 128
w = 128
d = 4

# %% [markdown]
# And now, we will actually sample the patches.

# %%
X_patches, Y_labels = pipeline.sample_patches_randomly(num_patches, d, h, w)
# Out:
# begin sample_patches_randomly function
# sampling patches

# %%
X_patches.shape
# Out:
# (24966, 4, 128, 128)

# %% [markdown]
# We will transform the data to `channels_last` Keras format.

# %%
X_patches = np.transpose(X_patches, (0, 2, 3, 1)).astype(np.float32)

# %% [markdown]
# Because this dataset only has four labels, we will have four classes when we one-hot encode the targets and then transform `y` to one-hot encode the targets.

# %%
Y_labels[Y_labels == 4] = 3

shp = Y_labels.shape[0]
Y_labels = Y_labels.reshape(-1)
Y_labels = np_utils.to_categorical(Y_labels).astype(np.uint8)
Y_labels = Y_labels.reshape(shp, h, w, 4)

# %% [markdown]
# Now we will shuffle the entire dataset.

# %%
shuffle = list(zip(X_patches, Y_labels))
np.random.seed(180)
np.random.shuffle(shuffle)
X_patches = np.array([shuffle[i][0] for i in range(len(shuffle))])
Y_labels = np.array([shuffle[i][1] for i in range(len(shuffle))])
del shuffle

# %%
print("size of the patches:", X_patches.shape)
print("size of their corresponding targets:", Y_labels.shape)
# Out:
# size of the patches: (24966, 128, 128, 4)
# size of their corresponding targets: (24966, 128, 128, 4)

# %% [markdown]
# And then we will save the patches just in case.

# %%
np.save('/Users/kaitlinylim/Documents/tumorproj/numpy/X_patches.npy', X_patches)
np.save('/Users/kaitlinylim/Documents/tumorproj/numpy/Y_labels.npy', Y_labels)

# %% [markdown]
# ## `Training` Execution
# Now to actually train the model, we will use the `Training` class we previously defined.

# %%
X_patches = np.load('/Users/kaitlinylim/Documents/tumorproj/numpy/X_patches.npy')
Y_labels = np.load('/Users/kaitlinylim/Documents/tumorproj/numpy/Y_labels.npy')

# %% [markdown]
# We will split the training data further into training data and validation data, 80% and 20% respectively.

# %%
# split the training data further into training data and validation data
div = int(X_patches.shape[0] * 0.8)
X_training = X_patches[0:div]
X_validation = X_patches[div:]
Y_training = Y_labels[0:div]
Y_validation = Y_labels[div:]

# %% [markdown]
# We will next compile the model using the `Training` class, with a `batch_size` of 4 and 2 epochs.

# %%
brain_seg_1 = Training(batch_size = 4, nb_epoch = 2)
# Out:
# u-net cnn compiled!
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`

# %% [markdown]
# Let's see how many trainable parameters there are in the CNN.

# %%
print("number of trainable parameters:", brain_seg_1.model.count_params())
print(brain_seg_1.model.summary())
# Out:
# number of trainable parameters: 10159748
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           (None, 128, 128, 4)  0
# __________________________________________________________________________________________________
# gaussian_noise_16 (GaussianNois (None, 128, 128, 4)  0           input_16[0][0]
# __________________________________________________________________________________________________
# conv2d_376 (Conv2D)             (None, 128, 128, 64) 1088        gaussian_noise_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 128, 128, 64) 256         conv2d_376[0][0]
# __________________________________________________________________________________________________
# p_re_lu_226 (PReLU)             (None, 128, 128, 64) 64          batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# conv2d_377 (Conv2D)             (None, 128, 128, 64) 36928       p_re_lu_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 128, 128, 64) 256         conv2d_377[0][0]
# __________________________________________________________________________________________________
# p_re_lu_227 (PReLU)             (None, 128, 128, 64) 64          batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# conv2d_378 (Conv2D)             (None, 128, 128, 64) 36928       p_re_lu_227[0][0]
# __________________________________________________________________________________________________
# add_106 (Add)                   (None, 128, 128, 64) 0           conv2d_376[0][0]
#                                                                  conv2d_378[0][0]
# __________________________________________________________________________________________________
# conv2d_379 (Conv2D)             (None, 64, 64, 128)  32896       add_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 64, 64, 128)  512         conv2d_379[0][0]
# __________________________________________________________________________________________________
# p_re_lu_228 (PReLU)             (None, 64, 64, 128)  128         batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# conv2d_380 (Conv2D)             (None, 64, 64, 128)  147584      p_re_lu_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 64, 64, 128)  512         conv2d_380[0][0]
# __________________________________________________________________________________________________
# p_re_lu_229 (PReLU)             (None, 64, 64, 128)  128         batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# conv2d_381 (Conv2D)             (None, 64, 64, 128)  147584      p_re_lu_229[0][0]
# __________________________________________________________________________________________________
# add_107 (Add)                   (None, 64, 64, 128)  0           conv2d_379[0][0]
#                                                                  conv2d_381[0][0]
# __________________________________________________________________________________________________
# conv2d_382 (Conv2D)             (None, 32, 32, 256)  131328      add_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 32, 32, 256)  1024        conv2d_382[0][0]
# __________________________________________________________________________________________________
# p_re_lu_230 (PReLU)             (None, 32, 32, 256)  256         batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv2d_383 (Conv2D)             (None, 32, 32, 256)  590080      p_re_lu_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 32, 32, 256)  1024        conv2d_383[0][0]
# __________________________________________________________________________________________________
# p_re_lu_231 (PReLU)             (None, 32, 32, 256)  256         batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# conv2d_384 (Conv2D)             (None, 32, 32, 256)  590080      p_re_lu_231[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, 32, 32, 256)  0           conv2d_382[0][0]
#                                                                  conv2d_384[0][0]
# __________________________________________________________________________________________________
# conv2d_385 (Conv2D)             (None, 16, 16, 512)  524800      add_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 16, 16, 512)  2048        conv2d_385[0][0]
# __________________________________________________________________________________________________
# p_re_lu_232 (PReLU)             (None, 16, 16, 512)  512         batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv2d_386 (Conv2D)             (None, 16, 16, 512)  2359808     p_re_lu_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 16, 16, 512)  2048        conv2d_386[0][0]
# __________________________________________________________________________________________________
# p_re_lu_233 (PReLU)             (None, 16, 16, 512)  512         batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# conv2d_387 (Conv2D)             (None, 16, 16, 512)  2359808     p_re_lu_233[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, 16, 16, 512)  0           conv2d_385[0][0]
#                                                                  conv2d_387[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_46 (UpSampling2D) (None, 32, 32, 512)  0           add_109[0][0]
# __________________________________________________________________________________________________
# conv2d_388 (Conv2D)             (None, 32, 32, 256)  524544      up_sampling2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 32, 32, 512)  0           add_108[0][0]
#                                                                  conv2d_388[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 32, 32, 512)  2048        concatenate_46[0][0]
# __________________________________________________________________________________________________
# p_re_lu_234 (PReLU)             (None, 32, 32, 512)  512         batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# conv2d_389 (Conv2D)             (None, 32, 32, 256)  1179904     p_re_lu_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 32, 32, 256)  1024        conv2d_389[0][0]
# __________________________________________________________________________________________________
# p_re_lu_235 (PReLU)             (None, 32, 32, 256)  256         batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# conv2d_391 (Conv2D)             (None, 32, 32, 256)  131072      concatenate_46[0][0]
# __________________________________________________________________________________________________
# conv2d_390 (Conv2D)             (None, 32, 32, 256)  590080      p_re_lu_235[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 32, 32, 256)  0           conv2d_391[0][0]
#                                                                  conv2d_390[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_47 (UpSampling2D) (None, 64, 64, 256)  0           add_110[0][0]
# __________________________________________________________________________________________________
# conv2d_392 (Conv2D)             (None, 64, 64, 128)  131200      up_sampling2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 64, 64, 256)  0           add_107[0][0]
#                                                                  conv2d_392[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 64, 64, 256)  1024        concatenate_47[0][0]
# __________________________________________________________________________________________________
# p_re_lu_236 (PReLU)             (None, 64, 64, 256)  256         batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_393 (Conv2D)             (None, 64, 64, 128)  295040      p_re_lu_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 64, 64, 128)  512         conv2d_393[0][0]
# __________________________________________________________________________________________________
# p_re_lu_237 (PReLU)             (None, 64, 64, 128)  128         batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# conv2d_395 (Conv2D)             (None, 64, 64, 128)  32768       concatenate_47[0][0]
# __________________________________________________________________________________________________
# conv2d_394 (Conv2D)             (None, 64, 64, 128)  147584      p_re_lu_237[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, 64, 64, 128)  0           conv2d_395[0][0]
#                                                                  conv2d_394[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_48 (UpSampling2D) (None, 128, 128, 128 0           add_111[0][0]
# __________________________________________________________________________________________________
# conv2d_396 (Conv2D)             (None, 128, 128, 64) 32832       up_sampling2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 128, 128, 128 0           add_106[0][0]
#                                                                  conv2d_396[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 128, 128, 128 512         concatenate_48[0][0]
# __________________________________________________________________________________________________
# p_re_lu_238 (PReLU)             (None, 128, 128, 128 128         batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_397 (Conv2D)             (None, 128, 128, 64) 73792       p_re_lu_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 128, 128, 64) 256         conv2d_397[0][0]
# __________________________________________________________________________________________________
# p_re_lu_239 (PReLU)             (None, 128, 128, 64) 64          batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# conv2d_399 (Conv2D)             (None, 128, 128, 64) 8192        concatenate_48[0][0]
# __________________________________________________________________________________________________
# conv2d_398 (Conv2D)             (None, 128, 128, 64) 36928       p_re_lu_239[0][0]
# __________________________________________________________________________________________________
# add_112 (Add)                   (None, 128, 128, 64) 0           conv2d_399[0][0]
#                                                                  conv2d_398[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 128, 128, 64) 256         add_112[0][0]
# __________________________________________________________________________________________________
# p_re_lu_240 (PReLU)             (None, 128, 128, 64) 64          batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_400 (Conv2D)             (None, 128, 128, 4)  260         p_re_lu_240[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 4)  0           conv2d_400[0][0]
# ==================================================================================================
# Total params: 10,159,748
# Trainable params: 10,153,092
# Non-trainable params: 6,656
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Now, we are using the patches that we have just created to train the model.

# %%
brain_seg_1.fit_unet(X_training, Y_training, X_validation, Y_validation)

# %% [markdown]
# After successfully training the model, we will now save it.

# %%
brain_seg_1.save_model('seg_2_epochs')
# Out:
# model saved

# %% [markdown]
# We will also create another model with four epochs instead of two. But instead of creating and training another model from scratch, we will instead load the model that we just saved and "resume" training.

# %%
model_to_load = 'seg_2_epochs'
brain_seg_2 = Training(batch_size = 4, nb_epoch = 2, load_model_resume_training = model_to_load)
# Out:
# Loading model seg_2_epochs
# model loaded.
# model compiled
# pre-trained model loaded!

# %% [markdown]
# As we did previously, we will train and save the model.

# %%
brain_seg_2.fit_unet(X_training, Y_training, X_validation, Y_validation)
brain_seg_2.save_model('seg_4_epochs')

# %% [markdown]
# ## `Prediction` Execution
# Now we will use the newly created model for predictions! We will first create an object in the `Prediction` class, which basically just loads a fresh U-Net model on which the weights will be loaded for predictions.

# %%
model_to_load = '/Users/kaitlinylim/Documents/tumorproj/weights/seg_2_epochs.hdf5'
brain_seg_pred = Prediction(batch_size_test = 2, load_model_path = model_to_load)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`
# u-net cnn model compiled

# %% [markdown]
# We will then predict each volume and then save them to a Numpy array. We will first use the testing data.

# %%
final_vol_stats = brain_seg_pred.predict_multiple_volumes(path_all_test, save = True, show = True)
# Out:
# volume id: HGG/Brats18_TCIA02_309_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_321_1
# 155/155 [==============================] - 287s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8037
# Dice core tumor score (tt sauf vert): 0.8337
# Dice enhancing tumor score (jaune):0.8119
# **********************************************
# Sensitivity complete tumor score : 0.9510
# Sensitivity core tumor score (tt sauf vert): 0.8909
# Sensitivity enhancing tumor score (jaune):0.8610
# ***********************************************
# Specificity complete tumor score : 0.9939
# Specificity core tumor score (tt sauf vert): 0.9984
# Specificity enhancing tumor score (jaune):0.9985
# ***********************************************
# Hausdorff complete tumor score : 14.5945
# Hausdorff core tumor score (tt sauf vert): 14.5945
# Hausdorff enhancing tumor score (jaune):6.4031
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA06_247_1
# 155/155 [==============================] - 279s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7651
# Dice core tumor score (tt sauf vert): 0.7925
# Dice enhancing tumor score (jaune):0.7200
# **********************************************
# Sensitivity complete tumor score : 0.9664
# Sensitivity core tumor score (tt sauf vert): 0.9017
# Sensitivity enhancing tumor score (jaune):0.8824
# ***********************************************
# Specificity complete tumor score : 0.9965
# Specificity core tumor score (tt sauf vert): 0.9985
# Specificity enhancing tumor score (jaune):0.9982
# ***********************************************
# Hausdorff complete tumor score : 9.6437
# Hausdorff core tumor score (tt sauf vert): 6.4031
# Hausdorff enhancing tumor score (jaune):5.4772
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AAG_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_491_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_235_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA03_138_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_APR_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_274_1
# 155/155 [==============================] - 286s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8182
# Dice core tumor score (tt sauf vert): 0.6991
# Dice enhancing tumor score (jaune):0.7289
# **********************************************
# Sensitivity complete tumor score : 0.9736
# Sensitivity core tumor score (tt sauf vert): 0.8847
# Sensitivity enhancing tumor score (jaune):0.9212
# ***********************************************
# Specificity complete tumor score : 0.9918
# Specificity core tumor score (tt sauf vert): 0.9954
# Specificity enhancing tumor score (jaune):0.9968
# ***********************************************
# Hausdorff complete tumor score : 17.0000
# Hausdorff core tumor score (tt sauf vert): 12.0830
# Hausdorff enhancing tumor score (jaune):8.9443
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA03_474_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_118_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ARF_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA03_265_1
# 155/155 [==============================] - 276s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7718
# Dice core tumor score (tt sauf vert): 0.6644
# Dice enhancing tumor score (jaune):0.4947
# **********************************************
# Sensitivity complete tumor score : 0.8833
# Sensitivity core tumor score (tt sauf vert): 0.7056
# Sensitivity enhancing tumor score (jaune):0.5964
# ***********************************************
# Specificity complete tumor score : 0.9972
# Specificity core tumor score (tt sauf vert): 0.9982
# Specificity enhancing tumor score (jaune):0.9984
# ***********************************************
# Hausdorff complete tumor score : 8.0623
# Hausdorff core tumor score (tt sauf vert): 8.9443
# Hausdorff enhancing tumor score (jaune):4.3589
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_ABO_1
# 155/155 [==============================] - 279s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8431
# Dice core tumor score (tt sauf vert): 0.7621
# Dice enhancing tumor score (jaune):0.7202
# **********************************************
# Sensitivity complete tumor score : 0.9086
# Sensitivity core tumor score (tt sauf vert): 0.7590
# Sensitivity enhancing tumor score (jaune):0.6340
# ***********************************************
# Specificity complete tumor score : 0.9948
# Specificity core tumor score (tt sauf vert): 0.9980
# Specificity enhancing tumor score (jaune):0.9993
# ***********************************************
# Hausdorff complete tumor score : 10.6301
# Hausdorff core tumor score (tt sauf vert): 12.0000
# Hausdorff enhancing tumor score (jaune):5.3852
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_ALX_1
# 155/155 [==============================] - 276s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6303
# Dice core tumor score (tt sauf vert): 0.5302
# Dice enhancing tumor score (jaune):0.3685
# **********************************************
# Sensitivity complete tumor score : 0.8677
# Sensitivity core tumor score (tt sauf vert): 0.5247
# Sensitivity enhancing tumor score (jaune):0.3340
# ***********************************************
# Specificity complete tumor score : 0.9954
# Specificity core tumor score (tt sauf vert): 0.9993
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 7.2801
# Hausdorff core tumor score (tt sauf vert): 6.1644
# Hausdorff enhancing tumor score (jaune):2.0000
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA08_436_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AXO_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA04_437_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_205_1
# 155/155 [==============================] - 280s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7724
# Dice core tumor score (tt sauf vert): 0.7358
# Dice enhancing tumor score (jaune):0.6349
# **********************************************
# Sensitivity complete tumor score : 0.9159
# Sensitivity core tumor score (tt sauf vert): 0.8454
# Sensitivity enhancing tumor score (jaune):0.7158
# ***********************************************
# Specificity complete tumor score : 0.9910
# Specificity core tumor score (tt sauf vert): 0.9935
# Specificity enhancing tumor score (jaune):0.9953
# ***********************************************
# Hausdorff complete tumor score : 10.0000
# Hausdorff core tumor score (tt sauf vert): 12.0416
# Hausdorff enhancing tumor score (jaune):6.0000
# ***************************************************************
#
#
# volume id: HGG/Brats18_2013_12_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AXN_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ARZ_1
# 155/155 [==============================] - 276s 2s/step
# ************************************************************
# Dice complete tumor score : 0.3919
# Dice core tumor score (tt sauf vert): 0.4289
# Dice enhancing tumor score (jaune):0.4284
# **********************************************
# Sensitivity complete tumor score : 0.6147
# Sensitivity core tumor score (tt sauf vert): 0.5860
# Sensitivity enhancing tumor score (jaune):0.6303
# ***********************************************
# Specificity complete tumor score : 0.9967
# Specificity core tumor score (tt sauf vert): 0.9998
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 3.6056
# Hausdorff core tumor score (tt sauf vert): 3.0000
# Hausdorff enhancing tumor score (jaune):2.8284
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA01_412_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ABB_1
# 155/155 [==============================] - 274s 2s/step
# ************************************************************
# Dice complete tumor score : 0.4498
# Dice core tumor score (tt sauf vert): 0.6123
# Dice enhancing tumor score (jaune):0.5868
# **********************************************
# Sensitivity complete tumor score : 0.6721
# Sensitivity core tumor score (tt sauf vert): 0.6158
# Sensitivity enhancing tumor score (jaune):0.5478
# ***********************************************
# Specificity complete tumor score : 0.9968
# Specificity core tumor score (tt sauf vert): 0.9994
# Specificity enhancing tumor score (jaune):0.9996
# ***********************************************
# Hausdorff complete tumor score : 4.4721
# Hausdorff core tumor score (tt sauf vert): 5.3852
# Hausdorff enhancing tumor score (jaune):4.1231
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA05_478_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA04_328_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ATP_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_BHB_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_147_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AXL_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASY_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_234_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_5_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_290_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ATX_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_203_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AUQ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQA_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_3_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_406_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_BFP_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASG_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_109_1
# 155/155 [==============================] - 274s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8858
# Dice core tumor score (tt sauf vert): 0.5826
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.9084
# Sensitivity core tumor score (tt sauf vert): 0.5695
# Sensitivity enhancing tumor score (jaune):0.0000
# ***********************************************
# Specificity complete tumor score : 0.9964
# Specificity core tumor score (tt sauf vert): 0.9975
# Specificity enhancing tumor score (jaune):1.0000
# ***********************************************
# Hausdorff complete tumor score : 7.0000
# Hausdorff core tumor score (tt sauf vert): 10.7703
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA09_255_1
# 155/155 [==============================] - 277s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8086
# Dice core tumor score (tt sauf vert): 0.2497
# Dice enhancing tumor score (jaune):0.1477
# **********************************************
# Sensitivity complete tumor score : 0.9026
# Sensitivity core tumor score (tt sauf vert): 0.1690
# Sensitivity enhancing tumor score (jaune):0.6544
# ***********************************************
# Specificity complete tumor score : 0.9912
# Specificity core tumor score (tt sauf vert): 0.9977
# Specificity enhancing tumor score (jaune):0.9990
# ***********************************************
# Hausdorff complete tumor score : 7.2801
# Hausdorff core tumor score (tt sauf vert): 5.0000
# Hausdorff enhancing tumor score (jaune):2.2361
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA13_653_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_202_1
# 155/155 [==============================] - 281s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8346
# Dice core tumor score (tt sauf vert): 0.5642
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.8416
# Sensitivity core tumor score (tt sauf vert): 0.5324
# Sensitivity enhancing tumor score (jaune):0.0000
# ***********************************************
# Specificity complete tumor score : 0.9971
# Specificity core tumor score (tt sauf vert): 0.9962
# Specificity enhancing tumor score (jaune):1.0000
# ***********************************************
# Hausdorff complete tumor score : 16.4317
# Hausdorff core tumor score (tt sauf vert): 15.9374
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA13_623_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_629_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA13_615_1
# 155/155 [==============================] - 274s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7200
# Dice core tumor score (tt sauf vert): 0.5722
# Dice enhancing tumor score (jaune):0.1436
# **********************************************
# Sensitivity complete tumor score : 0.8518
# Sensitivity core tumor score (tt sauf vert): 0.4555
# Sensitivity enhancing tumor score (jaune):0.7035
# ***********************************************
# Specificity complete tumor score : 0.9927
# Specificity core tumor score (tt sauf vert): 0.9981
# Specificity enhancing tumor score (jaune):0.9989
# ***********************************************
# Hausdorff complete tumor score : 7.1414
# Hausdorff core tumor score (tt sauf vert): 4.5826
# Hausdorff enhancing tumor score (jaune):3.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA13_618_1
# 155/155 [==============================] - 276s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7170
# Dice core tumor score (tt sauf vert): 0.0046
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.8344
# Sensitivity core tumor score (tt sauf vert): 0.0024
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9962
# Specificity core tumor score (tt sauf vert): 0.9996
# Specificity enhancing tumor score (jaune):1.0000
# ***********************************************
# Hausdorff complete tumor score : 8.6603
# Hausdorff core tumor score (tt sauf vert): 1.7321
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_261_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_2013_6_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA13_650_1
# 155/155 [==============================] - 272s 2s/step
# ************************************************************
# Dice complete tumor score : 0.2655
# Dice core tumor score (tt sauf vert): 0.3136
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.4475
# Sensitivity core tumor score (tt sauf vert): 0.4150
# Sensitivity enhancing tumor score (jaune):0.0000
# ***********************************************
# Specificity complete tumor score : 0.9963
# Specificity core tumor score (tt sauf vert): 0.9987
# Specificity enhancing tumor score (jaune):0.9996
# ***********************************************
# Hausdorff complete tumor score : 4.1231
# Hausdorff core tumor score (tt sauf vert): 4.3589
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA12_470_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA12_101_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA09_312_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA13_621_1
# there is a problem here! the problem lies in this patient
# mean: [0.69852775 0.55639527 0.38571464 0.83597853 0.59052156 0.56538213
#  0.99494038 0.99786233 0.99887513 9.06166304 3.38375241 3.38375241]
# std: [1.78164556e-01 2.18759283e-01 3.00000621e-01 1.41612668e-01
#  2.53184470e-01 3.24104457e-01 2.15378299e-03 1.64177411e-03
#  1.28437961e-03 4.01907073e+00 2.66149449e+00 2.66149449e+00]
# median: [0.77178531 0.58257958 0.42839952 0.88330903 0.58599779 0.63397576
#  0.99619931 0.99815905 0.99927454 8.06225775 3.         3.        ]
# 25 quartile: [0.67361714 0.47955597 0.07178874 0.83799886 0.49013149 0.44091668
#  0.99327143 0.99758173 0.99848543 7.07071421 1.         1.        ]
# 75 quartile: [ 0.8134238   0.7174735   0.67746097  0.91227359  0.8022186   0.78837353
#   0.99663048  0.99895526  0.99978785 10.31507291  5.43119519  5.43119519]
# max: [ 0.88583275  0.83374816  0.8119263   0.97362878  0.90167462  1.
#   0.99723873  0.99976698  0.99999731 17.          8.94427191  8.94427191]
# min: [2.65476583e-01 4.55977757e-03 0.00000000e+00 4.47488584e-01
#  2.44576564e-03 0.00000000e+00 9.91013357e-01 9.93485042e-01
#  9.95263058e-01 3.60555128e+00 0.00000000e+00 0.00000000e+00]

# %% [markdown]
# And because the current amount of testing data would likely not be enough for the training of the classification models, we will also use the CNN to predict the training data.

# %%
final_vol_stats_2 = brain_seg_pred.predict_multiple_volumes(path_all_train, save = True, show = True)
# Out:
# volume id: HGG/Brats18_TCIA04_149_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA06_211_1
# 155/155 [==============================] - 283s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8569
# Dice core tumor score (tt sauf vert): 0.7875
# Dice enhancing tumor score (jaune):0.7885
# **********************************************
# Sensitivity complete tumor score : 0.8688
# Sensitivity core tumor score (tt sauf vert): 0.8795
# Sensitivity enhancing tumor score (jaune):0.8338
# ***********************************************
# Specificity complete tumor score : 0.9972
# Specificity core tumor score (tt sauf vert): 0.9969
# Specificity enhancing tumor score (jaune):0.9978
# ***********************************************
# Hausdorff complete tumor score : 10.3441
# Hausdorff core tumor score (tt sauf vert): 13.1529
# Hausdorff enhancing tumor score (jaune):11.1803
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_ATD_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_390_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_283_1
# 155/155 [==============================] - 276s 2s/step
# ************************************************************
# Dice complete tumor score : 0.5703
# Dice core tumor score (tt sauf vert): 0.5119
# Dice enhancing tumor score (jaune):0.5227
# **********************************************
# Sensitivity complete tumor score : 0.6063
# Sensitivity core tumor score (tt sauf vert): 0.5167
# Sensitivity enhancing tumor score (jaune):0.4019
# ***********************************************
# Specificity complete tumor score : 0.9960
# Specificity core tumor score (tt sauf vert): 0.9995
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 10.2470
# Hausdorff core tumor score (tt sauf vert): 4.4721
# Hausdorff enhancing tumor score (jaune):3.0000
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_ASE_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AOZ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_460_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_162_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_499_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA04_111_1
# 155/155 [==============================] - 279s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7965
# Dice core tumor score (tt sauf vert): 0.6717
# Dice enhancing tumor score (jaune):0.6755
# **********************************************
# Sensitivity complete tumor score : 0.8293
# Sensitivity core tumor score (tt sauf vert): 0.6991
# Sensitivity enhancing tumor score (jaune):0.6326
# ***********************************************
# Specificity complete tumor score : 0.9979
# Specificity core tumor score (tt sauf vert): 0.9994
# Specificity enhancing tumor score (jaune):0.9997
# ***********************************************
# Hausdorff complete tumor score : 9.4340
# Hausdorff core tumor score (tt sauf vert): 7.4833
# Hausdorff enhancing tumor score (jaune):3.0000
# ***************************************************************
#
#
# volume id: HGG/Brats18_2013_19_1
# 155/155 [==============================] - 280s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7319
# Dice core tumor score (tt sauf vert): 0.6409
# Dice enhancing tumor score (jaune):0.4692
# **********************************************
# Sensitivity complete tumor score : 0.7623
# Sensitivity core tumor score (tt sauf vert): 0.6089
# Sensitivity enhancing tumor score (jaune):0.3912
# ***********************************************
# Specificity complete tumor score : 0.9971
# Specificity core tumor score (tt sauf vert): 0.9985
# Specificity enhancing tumor score (jaune):0.9994
# ***********************************************
# Hausdorff complete tumor score : 7.8102
# Hausdorff core tumor score (tt sauf vert): 5.7446
# Hausdorff enhancing tumor score (jaune):4.2426
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA05_277_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AUN_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ATF_1
# 155/155 [==============================] - 288s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6605
# Dice core tumor score (tt sauf vert): 0.2590
# Dice enhancing tumor score (jaune):0.3778
# **********************************************
# Sensitivity complete tumor score : 0.7579
# Sensitivity core tumor score (tt sauf vert): 0.4069
# Sensitivity enhancing tumor score (jaune):0.4799
# ***********************************************
# Specificity complete tumor score : 0.9944
# Specificity core tumor score (tt sauf vert): 0.9967
# Specificity enhancing tumor score (jaune):0.9992
# ***********************************************
# Hausdorff complete tumor score : 8.3666
# Hausdorff core tumor score (tt sauf vert): 9.2736
# Hausdorff enhancing tumor score (jaune):3.1623
# ***************************************************************
#
#
# volume id: HGG/Brats18_2013_20_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_448_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_374_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_401_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AVG_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_14_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AOD_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_APZ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_378_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AXM_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQR_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_4_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AYI_1
# 155/155 [==============================] - 283s 2s/step
# ************************************************************
# Dice complete tumor score : 0.4681
# Dice core tumor score (tt sauf vert): 0.6637
# Dice enhancing tumor score (jaune):0.4929
# **********************************************
# Sensitivity complete tumor score : 0.5896
# Sensitivity core tumor score (tt sauf vert): 0.6736
# Sensitivity enhancing tumor score (jaune):0.7898
# ***********************************************
# Specificity complete tumor score : 0.9992
# Specificity core tumor score (tt sauf vert): 0.9999
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 2.2361
# Hausdorff core tumor score (tt sauf vert): 2.4495
# Hausdorff enhancing tumor score (jaune):4.5826
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA01_150_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQN_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ABE_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_11_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_430_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA03_296_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AMH_1
# 155/155 [==============================] - 280s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8041
# Dice core tumor score (tt sauf vert): 0.6661
# Dice enhancing tumor score (jaune):0.7008
# **********************************************
# Sensitivity complete tumor score : 0.9349
# Sensitivity core tumor score (tt sauf vert): 0.6321
# Sensitivity enhancing tumor score (jaune):0.7923
# ***********************************************
# Specificity complete tumor score : 0.9944
# Specificity core tumor score (tt sauf vert): 0.9995
# Specificity enhancing tumor score (jaune):0.9995
# ***********************************************
# Hausdorff complete tumor score : 12.2066
# Hausdorff core tumor score (tt sauf vert): 7.0000
# Hausdorff enhancing tumor score (jaune):4.1231
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AQT_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA06_603_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_113_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA04_479_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_314_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_13_1
# 155/155 [==============================] - 281s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6323
# Dice core tumor score (tt sauf vert): 0.3853
# Dice enhancing tumor score (jaune):0.4806
# **********************************************
# Sensitivity complete tumor score : 0.7747
# Sensitivity core tumor score (tt sauf vert): 0.3871
# Sensitivity enhancing tumor score (jaune):0.3794
# ***********************************************
# Specificity complete tumor score : 0.9984
# Specificity core tumor score (tt sauf vert): 0.9997
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 6.0828
# Hausdorff core tumor score (tt sauf vert): 3.0000
# Hausdorff enhancing tumor score (jaune):3.3166
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AWH_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASW_1
# 155/155 [==============================] - 280s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7898
# Dice core tumor score (tt sauf vert): 0.7779
# Dice enhancing tumor score (jaune):0.7754
# **********************************************
# Sensitivity complete tumor score : 0.9033
# Sensitivity core tumor score (tt sauf vert): 0.8553
# Sensitivity enhancing tumor score (jaune):0.8236
# ***********************************************
# Specificity complete tumor score : 0.9965
# Specificity core tumor score (tt sauf vert): 0.9985
# Specificity enhancing tumor score (jaune):0.9990
# ***********************************************
# Hausdorff complete tumor score : 7.2801
# Hausdorff core tumor score (tt sauf vert): 9.3808
# Hausdorff enhancing tumor score (jaune):4.1231
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AME_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ABN_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_608_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_322_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ANZ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQJ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_180_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AVV_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_606_1
# 155/155 [==============================] - 297s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7304
# Dice core tumor score (tt sauf vert): 0.6706
# Dice enhancing tumor score (jaune):0.5091
# **********************************************
# Sensitivity complete tumor score : 0.9519
# Sensitivity core tumor score (tt sauf vert): 0.7629
# Sensitivity enhancing tumor score (jaune):0.7093
# ***********************************************
# Specificity complete tumor score : 0.9862
# Specificity core tumor score (tt sauf vert): 0.9942
# Specificity enhancing tumor score (jaune):0.9966
# ***********************************************
# Hausdorff complete tumor score : 20.6882
# Hausdorff core tumor score (tt sauf vert): 13.8924
# Hausdorff enhancing tumor score (jaune):6.4031
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_ASU_1
# 155/155 [==============================] - 334s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7328
# Dice core tumor score (tt sauf vert): 0.7177
# Dice enhancing tumor score (jaune):0.6791
# **********************************************
# Sensitivity complete tumor score : 0.9147
# Sensitivity core tumor score (tt sauf vert): 0.8232
# Sensitivity enhancing tumor score (jaune):0.7424
# ***********************************************
# Specificity complete tumor score : 0.9970
# Specificity core tumor score (tt sauf vert): 0.9991
# Specificity enhancing tumor score (jaune):0.9995
# ***********************************************
# Hausdorff complete tumor score : 9.1104
# Hausdorff core tumor score (tt sauf vert): 7.8102
# Hausdorff enhancing tumor score (jaune):3.6056
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA06_165_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_208_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AOH_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_222_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_26_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_218_1
# 155/155 [==============================] - 335s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8203
# Dice core tumor score (tt sauf vert): 0.7395
# Dice enhancing tumor score (jaune):0.8227
# **********************************************
# Sensitivity complete tumor score : 0.9276
# Sensitivity core tumor score (tt sauf vert): 0.8063
# Sensitivity enhancing tumor score (jaune):0.8040
# ***********************************************
# Specificity complete tumor score : 0.9969
# Specificity core tumor score (tt sauf vert): 0.9991
# Specificity enhancing tumor score (jaune):0.9997
# ***********************************************
# Hausdorff complete tumor score : 8.1854
# Hausdorff core tumor score (tt sauf vert): 9.1652
# Hausdorff enhancing tumor score (jaune):2.8284
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AQU_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ABY_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA03_121_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_21_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQQ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_105_1
# 155/155 [==============================] - 327s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8065
# Dice core tumor score (tt sauf vert): 0.8143
# Dice enhancing tumor score (jaune):0.7070
# **********************************************
# Sensitivity complete tumor score : 0.8452
# Sensitivity core tumor score (tt sauf vert): 0.8697
# Sensitivity enhancing tumor score (jaune):0.8420
# ***********************************************
# Specificity complete tumor score : 0.9961
# Specificity core tumor score (tt sauf vert): 0.9975
# Specificity enhancing tumor score (jaune):0.9968
# ***********************************************
# Hausdorff complete tumor score : 10.7703
# Hausdorff core tumor score (tt sauf vert): 10.1980
# Hausdorff enhancing tumor score (jaune):7.0000
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA03_338_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA03_498_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_117_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_368_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQP_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA05_396_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AOO_1
# 155/155 [==============================] - 292s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7591
# Dice core tumor score (tt sauf vert): 0.7005
# Dice enhancing tumor score (jaune):0.6765
# **********************************************
# Sensitivity complete tumor score : 0.9221
# Sensitivity core tumor score (tt sauf vert): 0.7908
# Sensitivity enhancing tumor score (jaune):0.7323
# ***********************************************
# Specificity complete tumor score : 0.9961
# Specificity core tumor score (tt sauf vert): 0.9984
# Specificity enhancing tumor score (jaune):0.9991
# ***********************************************
# Hausdorff complete tumor score : 10.0499
# Hausdorff core tumor score (tt sauf vert): 10.2470
# Hausdorff enhancing tumor score (jaune):3.1623
# ***************************************************************
#
#
# volume id: HGG/Brats18_2013_23_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AAB_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_179_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_429_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_171_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ANG_1
# 155/155 [==============================] - 272s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7401
# Dice core tumor score (tt sauf vert): 0.7100
# Dice enhancing tumor score (jaune):0.5102
# **********************************************
# Sensitivity complete tumor score : 0.9775
# Sensitivity core tumor score (tt sauf vert): 0.7363
# Sensitivity enhancing tumor score (jaune):0.8788
# ***********************************************
# Specificity complete tumor score : 0.9904
# Specificity core tumor score (tt sauf vert): 0.9984
# Specificity enhancing tumor score (jaune):0.9977
# ***********************************************
# Hausdorff complete tumor score : 16.3095
# Hausdorff core tumor score (tt sauf vert): 9.4868
# Hausdorff enhancing tumor score (jaune):8.6603
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA02_473_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ALN_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6410
# Dice core tumor score (tt sauf vert): 0.5393
# Dice enhancing tumor score (jaune):0.5538
# **********************************************
# Sensitivity complete tumor score : 0.9309
# Sensitivity core tumor score (tt sauf vert): 0.7294
# Sensitivity enhancing tumor score (jaune):0.8417
# ***********************************************
# Specificity complete tumor score : 0.9940
# Specificity core tumor score (tt sauf vert): 0.9989
# Specificity enhancing tumor score (jaune):0.9992
# ***********************************************
# Hausdorff complete tumor score : 10.7238
# Hausdorff core tumor score (tt sauf vert): 7.0711
# Hausdorff enhancing tumor score (jaune):4.1231
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA04_192_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQZ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASN_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_18_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_201_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8480
# Dice core tumor score (tt sauf vert): 0.7959
# Dice enhancing tumor score (jaune):0.7115
# **********************************************
# Sensitivity complete tumor score : 0.9208
# Sensitivity core tumor score (tt sauf vert): 0.8780
# Sensitivity enhancing tumor score (jaune):0.7955
# ***********************************************
# Specificity complete tumor score : 0.9956
# Specificity core tumor score (tt sauf vert): 0.9974
# Specificity enhancing tumor score (jaune):0.9978
# ***********************************************
# Hausdorff complete tumor score : 5.8310
# Hausdorff core tumor score (tt sauf vert): 13.3417
# Hausdorff enhancing tumor score (jaune):7.0000
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AYW_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA03_133_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6640
# Dice core tumor score (tt sauf vert): 0.1693
# Dice enhancing tumor score (jaune):0.0991
# **********************************************
# Sensitivity complete tumor score : 0.8835
# Sensitivity core tumor score (tt sauf vert): 0.1045
# Sensitivity enhancing tumor score (jaune):0.0576
# ***********************************************
# Specificity complete tumor score : 0.9973
# Specificity core tumor score (tt sauf vert): 0.9998
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 7.0000
# Hausdorff core tumor score (tt sauf vert): 4.2426
# Hausdorff enhancing tumor score (jaune):2.8284
# ***************************************************************
#
#
# volume id: HGG/Brats18_2013_22_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA06_332_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8273
# Dice core tumor score (tt sauf vert): 0.6526
# Dice enhancing tumor score (jaune):0.6525
# **********************************************
# Sensitivity complete tumor score : 0.8974
# Sensitivity core tumor score (tt sauf vert): 0.6624
# Sensitivity enhancing tumor score (jaune):0.6511
# ***********************************************
# Specificity complete tumor score : 0.9952
# Specificity core tumor score (tt sauf vert): 0.9992
# Specificity enhancing tumor score (jaune):0.9994
# ***********************************************
# Hausdorff complete tumor score : 14.7986
# Hausdorff core tumor score (tt sauf vert): 8.1240
# Hausdorff enhancing tumor score (jaune):4.1231
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AQD_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_280_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AUR_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_27_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA05_444_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AVJ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA04_343_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7277
# Dice core tumor score (tt sauf vert): 0.5686
# Dice enhancing tumor score (jaune):0.6444
# **********************************************
# Sensitivity complete tumor score : 0.7595
# Sensitivity core tumor score (tt sauf vert): 0.5422
# Sensitivity enhancing tumor score (jaune):0.5983
# ***********************************************
# Specificity complete tumor score : 0.9980
# Specificity core tumor score (tt sauf vert): 0.9997
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 7.2801
# Hausdorff core tumor score (tt sauf vert): 2.2361
# Hausdorff enhancing tumor score (jaune):3.0000
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA03_419_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_471_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AOP_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ATV_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AYA_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_335_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AAL_1
# 155/155 [==============================] - 274s 2s/step
# ************************************************************
# Dice complete tumor score : 0.4578
# Dice core tumor score (tt sauf vert): 0.4929
# Dice enhancing tumor score (jaune):0.6558
# **********************************************
# Sensitivity complete tumor score : 0.8955
# Sensitivity core tumor score (tt sauf vert): 0.8738
# Sensitivity enhancing tumor score (jaune):0.8012
# ***********************************************
# Specificity complete tumor score : 0.9932
# Specificity core tumor score (tt sauf vert): 0.9993
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 10.6771
# Hausdorff core tumor score (tt sauf vert): 6.0000
# Hausdorff enhancing tumor score (jaune):4.1231
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA02_226_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_198_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_190_1
# 155/155 [==============================] - 269s 2s/step
# ************************************************************
# Dice complete tumor score : 0.4667
# Dice core tumor score (tt sauf vert): 0.0400
# Dice enhancing tumor score (jaune):0.0070
# **********************************************
# Sensitivity complete tumor score : 0.3597
# Sensitivity core tumor score (tt sauf vert): 0.0215
# Sensitivity enhancing tumor score (jaune):0.0037
# ***********************************************
# Specificity complete tumor score : 0.9995
# Specificity core tumor score (tt sauf vert): 0.9999
# Specificity enhancing tumor score (jaune):1.0000
# ***********************************************
# Hausdorff complete tumor score : 4.0000
# Hausdorff core tumor score (tt sauf vert): 1.4142
# Hausdorff enhancing tumor score (jaune):1.7321
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AXJ_1
# 155/155 [==============================] - 269s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7336
# Dice core tumor score (tt sauf vert): 0.5112
# Dice enhancing tumor score (jaune):0.6215
# **********************************************
# Sensitivity complete tumor score : 0.9610
# Sensitivity core tumor score (tt sauf vert): 0.6108
# Sensitivity enhancing tumor score (jaune):0.5677
# ***********************************************
# Specificity complete tumor score : 0.9884
# Specificity core tumor score (tt sauf vert): 0.9983
# Specificity enhancing tumor score (jaune):0.9996
# ***********************************************
# Hausdorff complete tumor score : 21.5870
# Hausdorff core tumor score (tt sauf vert): 7.6811
# Hausdorff enhancing tumor score (jaune):3.1623
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AQG_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA06_372_1
# 155/155 [==============================] - 269s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8503
# Dice core tumor score (tt sauf vert): 0.7873
# Dice enhancing tumor score (jaune):0.7226
# **********************************************
# Sensitivity complete tumor score : 0.9502
# Sensitivity core tumor score (tt sauf vert): 0.8454
# Sensitivity enhancing tumor score (jaune):0.8321
# ***********************************************
# Specificity complete tumor score : 0.9926
# Specificity core tumor score (tt sauf vert): 0.9976
# Specificity enhancing tumor score (jaune):0.9975
# ***********************************************
# Hausdorff complete tumor score : 13.1529
# Hausdorff core tumor score (tt sauf vert): 11.3578
# Hausdorff enhancing tumor score (jaune):7.2801
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_ABM_1
# 155/155 [==============================] - 269s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7004
# Dice core tumor score (tt sauf vert): 0.6264
# Dice enhancing tumor score (jaune):0.6759
# **********************************************
# Sensitivity complete tumor score : 0.9392
# Sensitivity core tumor score (tt sauf vert): 0.7275
# Sensitivity enhancing tumor score (jaune):0.7327
# ***********************************************
# Specificity complete tumor score : 0.9967
# Specificity core tumor score (tt sauf vert): 0.9994
# Specificity enhancing tumor score (jaune):0.9997
# ***********************************************
# Hausdorff complete tumor score : 9.4868
# Hausdorff core tumor score (tt sauf vert): 7.8102
# Hausdorff enhancing tumor score (jaune):2.2361
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_BFB_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_319_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_231_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_370_1
# 155/155 [==============================] - 269s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8293
# Dice core tumor score (tt sauf vert): 0.7921
# Dice enhancing tumor score (jaune):0.7246
# **********************************************
# Sensitivity complete tumor score : 0.8898
# Sensitivity core tumor score (tt sauf vert): 0.8653
# Sensitivity enhancing tumor score (jaune):0.8380
# ***********************************************
# Specificity complete tumor score : 0.9969
# Specificity core tumor score (tt sauf vert): 0.9980
# Specificity enhancing tumor score (jaune):0.9984
# ***********************************************
# Hausdorff complete tumor score : 8.1854
# Hausdorff core tumor score (tt sauf vert): 8.3066
# Hausdorff enhancing tumor score (jaune):5.6569
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA02_168_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ATB_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_394_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASK_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ALU_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_242_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8516
# Dice core tumor score (tt sauf vert): 0.8039
# Dice enhancing tumor score (jaune):0.8198
# **********************************************
# Sensitivity complete tumor score : 0.9138
# Sensitivity core tumor score (tt sauf vert): 0.8627
# Sensitivity enhancing tumor score (jaune):0.8739
# ***********************************************
# Specificity complete tumor score : 0.9959
# Specificity core tumor score (tt sauf vert): 0.9978
# Specificity enhancing tumor score (jaune):0.9983
# ***********************************************
# Hausdorff complete tumor score : 12.2474
# Hausdorff core tumor score (tt sauf vert): 9.0554
# Hausdorff enhancing tumor score (jaune):5.9161
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA01_131_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQY_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_10_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ARW_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AXW_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_469_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_135_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_331_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_2_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ANP_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA06_184_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASV_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQO_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_APY_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_25_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_BHK_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_455_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AXQ_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AWG_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AWI_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6149
# Dice core tumor score (tt sauf vert): 0.5453
# Dice enhancing tumor score (jaune):0.4806
# **********************************************
# Sensitivity complete tumor score : 0.9098
# Sensitivity core tumor score (tt sauf vert): 0.4821
# Sensitivity enhancing tumor score (jaune):0.5262
# ***********************************************
# Specificity complete tumor score : 0.9932
# Specificity core tumor score (tt sauf vert): 0.9989
# Specificity enhancing tumor score (jaune):0.9991
# ***********************************************
# Hausdorff complete tumor score : 8.1240
# Hausdorff core tumor score (tt sauf vert): 9.6954
# Hausdorff enhancing tumor score (jaune):4.5826
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA08_278_1
# 155/155 [==============================] - 268s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6281
# Dice core tumor score (tt sauf vert): 0.6019
# Dice enhancing tumor score (jaune):0.5666
# **********************************************
# Sensitivity complete tumor score : 0.8858
# Sensitivity core tumor score (tt sauf vert): 0.7676
# Sensitivity enhancing tumor score (jaune):0.7842
# ***********************************************
# Specificity complete tumor score : 0.9925
# Specificity core tumor score (tt sauf vert): 0.9956
# Specificity enhancing tumor score (jaune):0.9971
# ***********************************************
# Hausdorff complete tumor score : 7.0000
# Hausdorff core tumor score (tt sauf vert): 8.6023
# Hausdorff enhancing tumor score (jaune):7.2111
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_BHM_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6416
# Dice core tumor score (tt sauf vert): 0.6539
# Dice enhancing tumor score (jaune):0.6974
# **********************************************
# Sensitivity complete tumor score : 0.6766
# Sensitivity core tumor score (tt sauf vert): 0.7128
# Sensitivity enhancing tumor score (jaune):0.6917
# ***********************************************
# Specificity complete tumor score : 0.9985
# Specificity core tumor score (tt sauf vert): 0.9994
# Specificity enhancing tumor score (jaune):0.9997
# ***********************************************
# Hausdorff complete tumor score : 7.0711
# Hausdorff core tumor score (tt sauf vert): 7.3485
# Hausdorff enhancing tumor score (jaune):3.0000
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA01_221_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AZD_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASA_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ANI_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AQV_1
# 155/155 [==============================] - 269s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6933
# Dice core tumor score (tt sauf vert): 0.6725
# Dice enhancing tumor score (jaune):0.6666
# **********************************************
# Sensitivity complete tumor score : 0.9547
# Sensitivity core tumor score (tt sauf vert): 0.7748
# Sensitivity enhancing tumor score (jaune):0.8151
# ***********************************************
# Specificity complete tumor score : 0.9953
# Specificity core tumor score (tt sauf vert): 0.9989
# Specificity enhancing tumor score (jaune):0.9991
# ***********************************************
# Hausdorff complete tumor score : 7.0711
# Hausdorff core tumor score (tt sauf vert): 7.4833
# Hausdorff enhancing tumor score (jaune):4.6904
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA02_607_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_17_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA03_375_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7892
# Dice core tumor score (tt sauf vert): 0.7958
# Dice enhancing tumor score (jaune):0.7312
# **********************************************
# Sensitivity complete tumor score : 0.9361
# Sensitivity core tumor score (tt sauf vert): 0.8005
# Sensitivity enhancing tumor score (jaune):0.6952
# ***********************************************
# Specificity complete tumor score : 0.9967
# Specificity core tumor score (tt sauf vert): 0.9991
# Specificity enhancing tumor score (jaune):0.9994
# ***********************************************
# Hausdorff complete tumor score : 7.0711
# Hausdorff core tumor score (tt sauf vert): 6.0828
# Hausdorff enhancing tumor score (jaune):3.1623
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA03_199_1
# 155/155 [==============================] - 276s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8490
# Dice core tumor score (tt sauf vert): 0.7523
# Dice enhancing tumor score (jaune):0.8373
# **********************************************
# Sensitivity complete tumor score : 0.9501
# Sensitivity core tumor score (tt sauf vert): 0.8959
# Sensitivity enhancing tumor score (jaune):0.8692
# ***********************************************
# Specificity complete tumor score : 0.9948
# Specificity core tumor score (tt sauf vert): 0.9982
# Specificity enhancing tumor score (jaune):0.9993
# ***********************************************
# Hausdorff complete tumor score : 11.0000
# Hausdorff core tumor score (tt sauf vert): 11.4891
# Hausdorff enhancing tumor score (jaune):4.5826
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA02_151_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7687
# Dice core tumor score (tt sauf vert): 0.6344
# Dice enhancing tumor score (jaune):0.6634
# **********************************************
# Sensitivity complete tumor score : 0.9068
# Sensitivity core tumor score (tt sauf vert): 0.6724
# Sensitivity enhancing tumor score (jaune):0.6977
# ***********************************************
# Specificity complete tumor score : 0.9943
# Specificity core tumor score (tt sauf vert): 0.9981
# Specificity enhancing tumor score (jaune):0.9991
# ***********************************************
# Hausdorff complete tumor score : 10.4403
# Hausdorff core tumor score (tt sauf vert): 11.5758
# Hausdorff enhancing tumor score (jaune):4.1231
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA02_377_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8869
# Dice core tumor score (tt sauf vert): 0.8228
# Dice enhancing tumor score (jaune):0.8487
# **********************************************
# Sensitivity complete tumor score : 0.9535
# Sensitivity core tumor score (tt sauf vert): 0.9027
# Sensitivity enhancing tumor score (jaune):0.8902
# ***********************************************
# Specificity complete tumor score : 0.9958
# Specificity core tumor score (tt sauf vert): 0.9981
# Specificity enhancing tumor score (jaune):0.9988
# ***********************************************
# Hausdorff complete tumor score : 9.4340
# Hausdorff core tumor score (tt sauf vert): 11.2250
# Hausdorff enhancing tumor score (jaune):5.8310
# ***************************************************************
#
#
# volume id: HGG/Brats18_TCIA01_425_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AZH_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_411_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASH_1
# 155/155 [==============================] - 277s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6288
# Dice core tumor score (tt sauf vert): 0.4738
# Dice enhancing tumor score (jaune):0.4253
# **********************************************
# Sensitivity complete tumor score : 0.6229
# Sensitivity core tumor score (tt sauf vert): 0.4993
# Sensitivity enhancing tumor score (jaune):0.3934
# ***********************************************
# Specificity complete tumor score : 0.9988
# Specificity core tumor score (tt sauf vert): 0.9998
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 6.1644
# Hausdorff core tumor score (tt sauf vert): 4.4721
# Hausdorff enhancing tumor score (jaune):1.7321
# ***************************************************************
#
#
# volume id: HGG/Brats18_CBICA_AYU_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA04_361_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA01_186_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_300_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_AAP_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_CBICA_ASO_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA08_167_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_2013_7_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA02_605_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA03_257_1
# there is a problem here! the problem lies in this patient
# volume id: HGG/Brats18_TCIA06_409_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_307_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7987
# Dice core tumor score (tt sauf vert): 0.4493
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.9163
# Sensitivity core tumor score (tt sauf vert): 0.3615
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9965
# Specificity core tumor score (tt sauf vert): 0.9990
# Specificity enhancing tumor score (jaune):1.0000
# ***********************************************
# Hausdorff complete tumor score : 8.5440
# Hausdorff core tumor score (tt sauf vert): 7.3485
# Hausdorff enhancing tumor score (jaune):2.2361
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_449_1
# 155/155 [==============================] - 270s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6902
# Dice core tumor score (tt sauf vert): 0.6745
# Dice enhancing tumor score (jaune):0.7811
# **********************************************
# Sensitivity complete tumor score : 0.9217
# Sensitivity core tumor score (tt sauf vert): 0.7155
# Sensitivity enhancing tumor score (jaune):0.7067
# ***********************************************
# Specificity complete tumor score : 0.9959
# Specificity core tumor score (tt sauf vert): 0.9987
# Specificity enhancing tumor score (jaune):0.9997
# ***********************************************
# Hausdorff complete tumor score : 6.4031
# Hausdorff core tumor score (tt sauf vert): 8.5440
# Hausdorff enhancing tumor score (jaune):9.4340
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_637_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA13_645_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_628_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_346_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_639_1
# 155/155 [==============================] - 272s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7329
# Dice core tumor score (tt sauf vert): 0.5307
# Dice enhancing tumor score (jaune):0.3098
# **********************************************
# Sensitivity complete tumor score : 0.9403
# Sensitivity core tumor score (tt sauf vert): 0.4169
# Sensitivity enhancing tumor score (jaune):0.4493
# ***********************************************
# Specificity complete tumor score : 0.9878
# Specificity core tumor score (tt sauf vert): 0.9985
# Specificity enhancing tumor score (jaune):0.9998
# ...
# volume id: LGG/Brats18_TCIA10_266_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA09_402_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_413_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_2013_0_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.3664
# Dice core tumor score (tt sauf vert): 0.6617
# Dice enhancing tumor score (jaune):0.8160
# **********************************************
# Sensitivity complete tumor score : 0.7567
# Sensitivity core tumor score (tt sauf vert): 0.6726
# Sensitivity enhancing tumor score (jaune):0.8285
# ***********************************************
# Specificity complete tumor score : 0.9867
# Specificity core tumor score (tt sauf vert): 0.9984
# Specificity enhancing tumor score (jaune):0.9996
# ***********************************************
# Hausdorff complete tumor score : 5.9161
# Hausdorff core tumor score (tt sauf vert): 3.7417
# Hausdorff enhancing tumor score (jaune):4.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_310_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_644_1
# 155/155 [==============================] - 272s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7886
# Dice core tumor score (tt sauf vert): 0.5220
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.9707
# Sensitivity core tumor score (tt sauf vert): 0.4952
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9911
# Specificity core tumor score (tt sauf vert): 0.9970
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 11.0000
# Hausdorff core tumor score (tt sauf vert): 11.5758
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA09_493_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6696
# Dice core tumor score (tt sauf vert): 0.1810
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.7204
# Sensitivity core tumor score (tt sauf vert): 0.1160
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9947
# Specificity core tumor score (tt sauf vert): 0.9989
# Specificity enhancing tumor score (jaune):0.9993
# ***********************************************
# Hausdorff complete tumor score : 11.6619
# Hausdorff core tumor score (tt sauf vert): 2.2361
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA09_462_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.6731
# Dice core tumor score (tt sauf vert): 0.1960
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.7948
# Sensitivity core tumor score (tt sauf vert): 0.3515
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9908
# Specificity core tumor score (tt sauf vert): 0.9945
# Specificity enhancing tumor score (jaune):0.9986
# ***********************************************
# Hausdorff complete tumor score : 6.6332
# Hausdorff core tumor score (tt sauf vert): 8.9443
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_410_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA09_141_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_351_1
# 155/155 [==============================] - 272s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8170
# Dice core tumor score (tt sauf vert): 0.6046
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.8570
# Sensitivity core tumor score (tt sauf vert): 0.6120
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9950
# Specificity core tumor score (tt sauf vert): 0.9955
# Specificity enhancing tumor score (jaune):1.0000
# ***********************************************
# Hausdorff complete tumor score : 19.1050
# Hausdorff core tumor score (tt sauf vert): 11.1803
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_130_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_2013_29_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_625_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA09_428_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_2013_15_1
# 155/155 [==============================] - 272s 2s/step
# ************************************************************
# Dice complete tumor score : 0.5706
# Dice core tumor score (tt sauf vert): 0.3216
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.9080
# Sensitivity core tumor score (tt sauf vert): 0.4156
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9956
# Specificity core tumor score (tt sauf vert): 0.9994
# Specificity enhancing tumor score (jaune):0.9995
# ***********************************************
# Hausdorff complete tumor score : 7.6158
# Hausdorff core tumor score (tt sauf vert): 4.1231
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_282_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_152_1
# 155/155 [==============================] - 273s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8535
# Dice core tumor score (tt sauf vert): 0.4341
# Dice enhancing tumor score (jaune):0.3832
# **********************************************
# Sensitivity complete tumor score : 0.9132
# Sensitivity core tumor score (tt sauf vert): 0.4376
# Sensitivity enhancing tumor score (jaune):0.2862
# ***********************************************
# Specificity complete tumor score : 0.9978
# Specificity core tumor score (tt sauf vert): 0.9992
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 7.8740
# Hausdorff core tumor score (tt sauf vert): 5.8310
# Hausdorff enhancing tumor score (jaune):2.4495
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_325_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_2013_28_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA13_624_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_393_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_2013_24_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_632_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA13_634_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.8099
# Dice core tumor score (tt sauf vert): 0.3526
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.8773
# Sensitivity core tumor score (tt sauf vert): 0.2647
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9955
# Specificity core tumor score (tt sauf vert): 0.9984
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 4.8990
# Hausdorff core tumor score (tt sauf vert): 10.0000
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA13_630_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7746
# Dice core tumor score (tt sauf vert): 0.5504
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.8890
# Sensitivity core tumor score (tt sauf vert): 0.4686
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9975
# Specificity core tumor score (tt sauf vert): 0.9991
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 4.6904
# Hausdorff core tumor score (tt sauf vert): 7.6811
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_490_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_2013_9_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_103_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7833
# Dice core tumor score (tt sauf vert): 0.4351
# Dice enhancing tumor score (jaune):0.7596
# **********************************************
# Sensitivity complete tumor score : 0.8840
# Sensitivity core tumor score (tt sauf vert): 0.7306
# Sensitivity enhancing tumor score (jaune):0.8220
# ***********************************************
# Specificity complete tumor score : 0.9906
# Specificity core tumor score (tt sauf vert): 0.9988
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 9.6437
# Hausdorff core tumor score (tt sauf vert): 6.7082
# Hausdorff enhancing tumor score (jaune):3.6056
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA12_249_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7196
# Dice core tumor score (tt sauf vert): 0.6042
# Dice enhancing tumor score (jaune):0.0043
# **********************************************
# Sensitivity complete tumor score : 0.9551
# Sensitivity core tumor score (tt sauf vert): 0.5332
# Sensitivity enhancing tumor score (jaune):0.0252
# ***********************************************
# Specificity complete tumor score : 0.9931
# Specificity core tumor score (tt sauf vert): 0.9984
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 6.3246
# Hausdorff core tumor score (tt sauf vert): 5.9161
# Hausdorff enhancing tumor score (jaune):1.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_2013_16_1
# 155/155 [==============================] - 271s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7491
# Dice core tumor score (tt sauf vert): 0.1214
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.8972
# Sensitivity core tumor score (tt sauf vert): 0.1789
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9964
# Specificity core tumor score (tt sauf vert): 0.9989
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 7.2801
# Hausdorff core tumor score (tt sauf vert): 5.8310
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA10_299_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA12_298_1
# 155/155 [==============================] - 273s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7922
# Dice core tumor score (tt sauf vert): 0.6959
# Dice enhancing tumor score (jaune):0.0000
# **********************************************
# Sensitivity complete tumor score : 0.9257
# Sensitivity core tumor score (tt sauf vert): 0.6145
# Sensitivity enhancing tumor score (jaune):1.0000
# ***********************************************
# Specificity complete tumor score : 0.9945
# Specificity core tumor score (tt sauf vert): 0.9986
# Specificity enhancing tumor score (jaune):0.9998
# ***********************************************
# Hausdorff complete tumor score : 6.0828
# Hausdorff core tumor score (tt sauf vert): 5.0990
# Hausdorff enhancing tumor score (jaune):0.0000
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA13_633_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_442_1
# 155/155 [==============================] - 273s 2s/step
# ************************************************************
# Dice complete tumor score : 0.7886
# Dice core tumor score (tt sauf vert): 0.5536
# Dice enhancing tumor score (jaune):0.4726
# **********************************************
# Sensitivity complete tumor score : 0.7072
# Sensitivity core tumor score (tt sauf vert): 0.3977
# Sensitivity enhancing tumor score (jaune):0.4075
# ***********************************************
# Specificity complete tumor score : 0.9989
# Specificity core tumor score (tt sauf vert): 0.9995
# Specificity enhancing tumor score (jaune):0.9999
# ***********************************************
# Hausdorff complete tumor score : 4.6904
# Hausdorff core tumor score (tt sauf vert): 5.3852
# Hausdorff enhancing tumor score (jaune):2.2361
# ***************************************************************
#
#
# volume id: LGG/Brats18_TCIA12_480_1
# there is a problem here! the problem lies in this patient
# volume id: LGG/Brats18_TCIA10_408_1
# there is a problem here! the problem lies in this patient
# mean: [0.72324015 0.55723503 0.46352315 0.85989985 0.59709276 0.71121447
#  0.9950195  0.9984061  0.99928163 9.09276839 3.42885073 3.42885073]
# std: [1.12656734e-01 1.99008887e-01 2.98844303e-01 1.14395182e-01
#  2.32489131e-01 2.56579389e-01 3.00782253e-03 1.29613778e-03
#  8.45667666e-04 3.73069086e+00 2.54382642e+00 2.54382642e+00]
# median: [0.74010227 0.60419555 0.52271021 0.89741627 0.66242442 0.79226838
#  0.99563892 0.99869066 0.99962578 8.18535277 3.16227766 3.16227766]
# 25 quartile: [0.66046025 0.46697225 0.09914052 0.83883521 0.43762392 0.56774787
#  0.99395179 0.99812535 0.99909498 7.         1.73205081 1.73205081]
# 75 quartile: [ 0.80410807  0.69588833  0.70083034  0.93085434  0.77484488  0.87386433
#   0.99688736  0.99930101  0.99985652 10.67707825  4.58257569  4.58257569]
# max: [ 0.88688861  0.82280436  0.84874851  0.97753737  0.9026746   1.
#   0.99950121  0.99994944  0.99998353 21.58703314 11.18033989 11.18033989]
# min: [0.36639511 0.04000428 0.         0.35974462 0.02146711 0.00366804
#  0.98617418 0.99419175 0.99662961 2.23606798 0.         0.        ]

# %% [markdown]
# Finally, we're finished! We will go through each predicted image and choose the predictions with a complete tumor Dice score of 0.7 or greater for classification. A Dice score of approximately 0.85 is quite good, but just to have a large enough repository of data for training and predicting, we will use predictions with scores of 0.70 or greater.
